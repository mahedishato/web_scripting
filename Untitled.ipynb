# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests
from bs4 import BeautifulSoup

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

webpage= requests.get('https://findoutadoctor.blogspot.com/2016/07/dhaka-hospital-address-and-phone-number.html', headers=header).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
soup.find_all('div')[10].text.strip()
# Out:
# ''

# %%
company= soup.find_all('div', class_= 'post-body')

# %%
soup.find_all('div', class_= 'post-body')[0].text.strip()
# Out:
# 'If you or someone in your family suddenly became sick. If you do not understand any of this moment to go to the hospital. Or you do not know any good hospital address and phone number. So I share with you today to help you address and phone number at the hospital. I hope everyone will benefit.\n\n\n\n\n\n\nClick on the Hospital Title To See Details.\n\nAd-din Hospital\n\nAsgar Ali Hospital, Gandaria\n\nAl Anaiet Adhunik Hospital\nCategory: General Hospital\nSpeciality:\nAddress: House # 36, Road # 3, Dhanmondi, Dhaka, Bangladesh\nPhone : +880-2-8631619\nSee Map\n\nAl-Ahsraf General Hospital\nCategory: General Hospital\nRead Details\xa0\n\nDr. Sirajul Islam Medical College Hospital\n\nAddress: 12/3, Outer Circular Rd, Dhaka, Bangladesh\n\nTelephone: +880 2-9351887\n\nLocation Map\n\nAbedin General Hospital and Consultation Center\nTel: +88 02 9133729\nLocation Map\n\nAl-Barakah Kidney Hospital\nCategory: Kidney & Dialysis Hospital\nAddress: 129, New Eskaton Road, Dhaka\nPhone : +880 
# ...

# %%
len(company)
# Out:
# 1

# %%
for i in soup.find_all('div', class_= 'post-body'):
    #print(i.text.strip())
    print
# Out:
# If you or someone in your family suddenly became sick. If you do not understand any of this moment to go to the hospital. Or you do not know any good hospital address and phone number. So I share with you today to help you address and phone number at the hospital. I hope everyone will benefit.
#
#
#
#
#
#
# Click on the Hospital Title To See Details.
#
# Ad-din Hospital
#
# Asgar Ali Hospital, Gandaria
#
# Al Anaiet Adhunik Hospital
# Category: General Hospital
# Speciality:
# Address: House # 36, Road # 3, Dhanmondi, Dhaka, Bangladesh
# Phone : +880-2-8631619
# See Map
#
# Al-Ahsraf General Hospital
# Category: General Hospital
# Read Details
#
# Dr. Sirajul Islam Medical College Hospital
#
# Address: 12/3, Outer Circular Rd, Dhaka, Bangladesh
#
# Telephone: +880 2-9351887
#
# Location Map
#
# Abedin General Hospital and Consultation Center
# Tel: +88 02 9133729
# Location Map
#
# Al-Barakah Kidney Hospital
# Category: Kidney & Dialysis Hospital
# ...

# %%
for i in soup.find_all('div', class_= 'post-body'):
    #print(i.text.strip())
    print(i.find('br').text.strip())
