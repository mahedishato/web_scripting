# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=2f6d7e7f9da203122461bcb95367f152967f955e347e9f4b48d6d47182a0ea83
#   Stored in directory: c:\users\mahed\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
import requests
#from bs4 import Be

# %%
from bs4 import BeautifulSoup

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

webpage= requests.get('https://www.ambitionbox.com/list-of-companies?page-1', headers=header).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
##print(soup.prettify())

# %%
soup.find_all('h1')[0].text
# Out:
# 'List of companies in India'

# %%
soup.find_all('h2')[0].text.strip()
# Out:
# 'TCS'

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# HDFC Bank
# Wipro
# Infosys
# Capgemini
# Tech Mahindra
# Genpact
# HCLTech
# Amazon
# Axis Bank
# IBM
# Concentrix Corpo...
# Reliance jio
# Larsen & Toubro ...
# HDB Financial Se...
# Vodafone Idea
# Teleperformance
# Kotak Mahindra B...
# Reliance Retail
# Deloitte
# Reliance Industr...
# Bharti Airtel
# Tata Motors
# BYJU'S
# Flipkart
# WNS
# Mahindra & Mahin...

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# AmbitionBox
# Discover Best Places to work in India
# AmbitionBox
# Discover best places to work
# Compare & find best workplace
# Read reviews for 6L+ companies
# Rate your former or current company
# Discover salaries for 6L+ companies
# Calculate your take home salary
# Check your market value
# Help other jobseekers
# Read interviews for 40K+ companies
# Interviews questions for 1K+ colleges
# Contribute your interview questions
# Discover Best Places to Work!
# Company reviews. Salaries. Interviews. Jobs.
# About Company
# 7,69,556 unique
# 			companies found
# Sort By:
# Popular
# 3.9
# #6 Best Mega Company - 2021
# Public
# Mumbai,Maharashtra + 268 more
# 54 years old
# 1 Lakh+ Employees (India)
# We ensure the highest levels of certainty and satisfaction through a deep-set commitment to our clients, comprehensive industry expertise and a global network of innovation and delivery centers.
#
# ...

# %%
for i in soup.find_all('p', class_='rating'):
    print(i.text.strip())
# Out:
# 3.9
# 4.1
# 4.0
# 4.0
# 4.0
# 3.9
# 3.9
# 3.9
# 3.7
# 4.0
# 3.8
# 4.3
# 3.9
# 4.2
# 4.0
# 4.0
# 4.1
# 4.0
# 4.2
# 3.6
# 3.9
# 4.1
# 4.1
# 4.1
# 4.1
# 4.1
# 3.5
# 4.2
# 3.7
# 3.9

# %%
for i in soup.find_all('a', class_='review-count'):
    print(i.text.strip())
# Out:
# (49.7k Reviews)
# (31.9k Reviews)
# (29.4k Reviews)
# (33.2k Reviews)
# (38.7k Reviews)
# (28.5k Reviews)
# (28k Reviews)
# (23.7k Reviews)
# (21.3k Reviews)
# (19.1k Reviews)
# (18.2k Reviews)
# (18.2k Reviews)
# (18.4k Reviews)
# (15.2k Reviews)
# (14.8k Reviews)
# (14.4k Reviews)
# (23.9k Reviews)
# (13.2k Reviews)
# (13.1k Reviews)
# (14.2k Reviews)
# (13.3k Reviews)
# (16k Reviews)
# (10.2k Reviews)
# (43.1k Reviews)
# (12.2k Reviews)
# (11.7k Reviews)
# (12.6k Reviews)
# (11.4k Reviews)
# (6.9k Reviews)
# (38.5k Reviews)

# %%
soup.find_all('i', class_='icon-domain')[0]
# Out:
# <i class="icon-domain"></i>

# %%
company= soup.find_all('div', class_= 'company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name=[]
rating = []
review= []
ctypes= []
headq=[]
age=[]
numbe_of_employee=[]
for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p', class_='rating').text.strip())
    review.append(i.find('a', class_='review-count').text.strip())
    ctypes.append(i.find('p', class_='infoEntity').text.strip())
    headq.append(i.find_all('p', class_= 'infoEntity')[1].text.strip())
    age.append(i.find_all('p', class_= 'infoEntity')[2].text.strip())
    numbe_of_employee.append(i.find_all('p', class_= 'infoEntity')[3].text.strip())

# %%
print(name,'*'*100,rating,'*'*100,review,'*'*100,ctypes,'*'*100,headq,'*'*100,age)
# Out:
# ['TCS', 'Accenture', 'Cognizant', 'ICICI Bank', 'HDFC Bank', 'Wipro', 'Infosys', 'Capgemini', 'Tech Mahindra', 'Genpact', 'HCLTech', 'Amazon', 'Axis Bank', 'IBM', 'Concentrix Corpo...', 'Reliance jio', 'Larsen & Toubro ...', 'HDB Financial Se...', 'Vodafone Idea', 'Teleperformance', 'Kotak Mahindra B...', 'Reliance Retail', 'Deloitte', 'Reliance Industr...', 'Bharti Airtel', 'Tata Motors', "BYJU'S", 'Flipkart', 'WNS', 'Mahindra & Mahin...'] **************************************************************************************************** ['3.9', '4.1', '4.0', '4.0', '4.0', '3.9', '3.9', '3.9', '3.7', '4.0', '3.8', '4.3', '3.9', '4.2', '4.0', '4.0', '4.1', '4.0', '4.2', '3.6', '3.9', '4.1', '4.1', '4.1', '4.1', '4.1', '3.5', '4.2', '3.7', '3.9'] **************************************************************************************************** ['(49.7k Reviews)', '(31.9k Reviews)', '(29.4k Reviews)', '(33.2k Reviews)', '(38.7k Reviews)', '(28.5k Reviews)', '(28k Reviews)', '(23.7k 
# ...

# %%
d = {'name':name, 'Rating':rating, 'Review':review, 'Company_type':ctypes, 'Head_quter':headq, 'Age':age, 'Number_of_employee':numbe_of_employee}
df = pd.DataFrame(d)

# %%
df
# Out:
#                    name Rating           Review Company_type  \
# 0                   TCS    3.9  (49.7k Reviews)       Public
# 1             Accenture    4.1  (31.9k Reviews)       Public
# 2             Cognizant    4.0  (29.4k Reviews)      Private
# 3            ICICI Bank    4.0  (33.2k Reviews)       Public
# 4             HDFC Bank    4.0  (38.7k Reviews)       Public
# 5                 Wipro    3.9  (28.5k Reviews)       Public
# 6               Infosys    3.9    (28k Reviews)       Public
# 7             Capgemini    3.9  (23.7k Reviews)       Public
# 8         Tech Mahindra    3.7  (21.3k Reviews)       Public
# 9               Genpact    4.0  (19.1k Reviews)       Public
# 10              HCLTech    3.8  (18.2k Reviews)       Public
# 11               Amazon    4.3  (18.2k Reviews)       Public
# 12            Axis Bank    3.9  (18.4k Reviews)       Public
# 13                  IBM    4.2  (15.2k Reviews)       Public
# ...

# %%
df.shape
# Out:
# (30, 7)

# %%
final = pd.DataFrame()

for j in range(1,50):
    url = 'https://www.ambitionbox.com/list-of-companies?page-{}'.format(j)
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

    webpage= requests.get(url, headers=header).text
    soup = BeautifulSoup(webpage, 'lxml')
    company= soup.find_all('div', class_= 'company-content-wrapper')
    name=[]
    rating = []
    review= []
    ctypes= []
    headq=[]
    age=[]
    numbe_of_employee=[]
    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('p', class_='rating').text.strip())
        review.append(i.find('a', class_='review-count').text.strip())
        ctypes.append(i.find('p', class_='infoEntity').text.strip())
        headq.append(i.find_all('p', class_= 'infoEntity')[1].text.strip())
        age.append(i.find_all('p', class_= 'infoEntity')[2].text.strip())
        try:
            numbe_of_employee.append(i.find_all('p', class_= 'infoEntity')[3].text.strip())
        except:
            numbe_of_employee.append(np.nan)
    d = {'name':name, 'Rating':rating, 'Review':review, 'Company_type':ctypes, 'Head_quter':headq, 'Age':age, 'Number_of_employee':numbe_of_employee}
    df = pd.DataFrame(d)
    final = final.append(df, ignore_index=True)
# Out:
# C:\Users\mahed\AppData\Local\Temp\ipykernel_10024\2047730449.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)

# %%
final
# Out:
#                      name Rating           Review Company_type  \
# 0                     TCS    3.9  (49.7k Reviews)       Public
# 1               Accenture    4.1  (31.9k Reviews)       Public
# 2               Cognizant    4.0  (29.4k Reviews)      Private
# 3              ICICI Bank    4.0  (33.2k Reviews)       Public
# 4               HDFC Bank    4.0  (38.7k Reviews)       Public
# ...                   ...    ...              ...          ...
# 1465          Tata Motors    4.1  (11.7k Reviews)       Public
# 1466               BYJU'S    3.5  (12.6k Reviews)      Private
# 1467             Flipkart    4.2  (11.4k Reviews)       Public
# 1468                  WNS    3.7   (6.9k Reviews)      Private
# 1469  Mahindra & Mahin...    3.9  (38.5k Reviews)       Public
#
#                            Head_quter           Age         Number_of_employee
# 0       Mumbai,Maharashtra + 268 more  54 years old  1 Lakh+ Employees (India)
# ...

# %%
final.shape
# Out:
# (1470, 7)
